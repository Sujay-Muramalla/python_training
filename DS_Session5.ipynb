# %%
a=1
b="sujay"
print (a,b)
# Out:
# 1 sujay

# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\Lenovo\\OneDrive\\Backup_23102024\\d_drive\\PERSONAL\\Career\\Programming\\Python\\Udemy\\Colt_Steele\\.venv\\Scripts\\python.exe'
