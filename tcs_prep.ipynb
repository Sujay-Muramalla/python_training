# %%
print ("hello")
# Out:
# hello

# %%
import sys

print(sys.executable)
# Out:
# c:\Python314\python.exe

# %%
l = list (range(1,10))
print (l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
name = "Sujay"
l = list (name)
print (l)

# %%
import sys
print(sys.executable)

# %%
print ("hello")
# Out:
# hello

# %%
name = "Sujay"
print (name.split())

l = list (name)
print (l)
# Out:
# ['Sujay']
# ['S', 'u', 'j', 'a', 'y']

# %%
nums = list (range(1,10))
print (nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
colors = ["red", "green", "blue"]
print (colors[1])
# Out:
# green

# %%
colors [-1]
# Out:
# 'blue'

# %%
'green' in colors
# Out:
# True

# %%
for num in nums:
    print (num*10)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90

# %%
colors
ind = 0
while ind < len(colors):
    print (f"{ind} : {colors[ind]}")
    ind+=1
# Out:
# 0 : red
# 1 : green
# 2 : blue

# %%
sounds = ["meow", "woof", "quack"]

for sound in sounds:
    print ("the animals say", sound)
    
result = ""
for sound in sounds:
    result+=sound.upper()
    
print (result)
# Out:
# the animals say meow
# the animals say woof
# the animals say quack
# MEOWWOOFQUACK

# %%
nums.append(2324)
print (nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 2324, 2324, 2324]

# %%
nums.extend ([1,2,3,4])
print (nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 2324, 2324, 2324, 1, 2, 3, 4, 1, 2, 3, 4]

# %%
index = 0

colors = ["red", "green", "blue", "yellow", "orange", "purple"]

while index < len(colors):
    print(f"{index}: {colors[index]}")
    index+=1
# Out:
# 0: red
# 1: green
# 2: blue
# 3: yellow
# 4: orange
# 5: purple

# %%
colors.append("magenta")

# %%
print (colors)
# Out:
# ['red', 'green', 'blue', 'yellow', 'orange', 'purple', 'magenta']

# %%
colors.insert (2, "cyn")

# %%
print (colors)
# Out:
# ['red', 'green', 'cyn', 'blue', 'yellow', 'orange', 'purple', 'magenta']

# %%
colors.insert(len(colors), "end")
print (colors)
# Out:
# ['red', 'green', 'cyn', 'blue', 'yellow', 'orange', 'purple', 'end', 'magenta', 'end']

# %%
colors.extend (["it is not the end", "it is just the beginning"])

# %%
print (colors)
# Out:
# ['red', 'green', 'cyn', 'blue', 'yellow', 'orange', 'purple', 'end', 'magenta', 'end', 'it is not the end', 'it is just the beginning']

# %%
colors.clear()

# %%
print (colors)
# Out:
# []

# %%
print (colors)
colors_popped = []
colors_popped.append(colors.pop())
print (colors)
print (colors_popped)
# Out:
# ['red', 'green', 'blue']
# ['red', 'green']
# ['blue']

# %%
index = 0

colors = ["red", "green", "blue", "yellow", "orange", "purple"]

while index < len(colors):
    print(f"{index}: {colors[index]}")
    index+=1
# Out:
# 0: red
# 1: green
# 2: blue
# 3: yellow
# 4: orange
# 5: purple

# %%
index = 0
colors_popped = []
length = len(colors)
while index < len(colors):
    colors_popped.append(colors.pop())
    len(colors) = length
    index+=1

print (f"colors: {colors}")
print (f"colors_popped: {colors_popped}")
# Out:
# colors: ['red', 'green', 'blue']
# colors_popped: ['purple', 'orange', 'yellow']
