# %%
print ("hello")
# Out:
# hello

# %%
import sys

print(sys.executable)
# Out:
# c:\Python314\python.exe

# %%
l = list (range(1,10))
print (l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
name = "Sujay"
l = list (name)
print (l)

# %%
import sys
print(sys.executable)

# %%
print ("hello")
# Out:
# hello

# %%
name = "Sujay"
print (name.split())

l = list (name)
print (l)
# Out:
# ['Sujay']
# ['S', 'u', 'j', 'a', 'y']

# %%
nums = list (range(1,10))
print (nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
colors = ["red", "green", "blue"]
print (colors[1])
# Out:
# green

# %%
colors [-1]
# Out:
# 'blue'

# %%
'green' in colors
# Out:
# True

# %%
for num in nums:
    print (num*10)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90

# %%
colors
ind = 0
while ind < len(colors):
    print (f"{ind} : {colors[ind]}")
    ind+=1
# Out:
# 0 : red
# 1 : green
# 2 : blue

# %%
sounds = ["meow", "woof", "quack"]

for sound in sounds:
    print ("the animals say", sound)
    
result = ""
for sound in sounds:
    result+=sound.upper()
    
print (result)
# Out:
# the animals say meow
# the animals say woof
# the animals say quack
# MEOWWOOFQUACK

# %%
nums.append(2324)
print (nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 2324, 2324, 2324]

# %%
nums.extend ([1,2,3,4])
print (nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 2324, 2324, 2324, 1, 2, 3, 4, 1, 2, 3, 4]

# %%
index = 0

colors = ["red", "green", "blue", "yellow", "orange", "purple"]

while index < len(colors):
    print(f"{index}: {colors[index]}")
    index+=1
# Out:
# 0: red
# 1: green
# 2: blue
# 3: yellow
# 4: orange
# 5: purple

# %%
colors.append("magenta")

# %%
print (colors)
# Out:
# ['red', 'green', 'blue', 'yellow', 'orange', 'purple', 'magenta']

# %%
colors.insert (2, "cyn")

# %%
print (colors)
# Out:
# ['red', 'green', 'cyn', 'blue', 'yellow', 'orange', 'purple', 'magenta']

# %%
colors.insert(len(colors), "end")
print (colors)
# Out:
# ['red', 'green', 'cyn', 'blue', 'yellow', 'orange', 'purple', 'end', 'magenta', 'end']

# %%
colors.extend (["it is not the end", "it is just the beginning"])

# %%
print (colors)
# Out:
# ['red', 'green', 'cyn', 'blue', 'yellow', 'orange', 'purple', 'end', 'magenta', 'end', 'it is not the end', 'it is just the beginning']

# %%
colors.clear()

# %%
print (colors)
# Out:
# []

# %%
print (colors)
colors_popped = []
colors_popped.append(colors.pop())
print (colors)
print (colors_popped)
# Out:
# ['red', 'green', 'blue']
# ['red', 'green']
# ['blue']

# %%
index = 0

colors = ["red", "green", "blue", "yellow", "orange", "purple"]

while index < len(colors):
    print(f"{index}: {colors[index]}")
    index+=1
# Out:
# 0: red
# 1: green
# 2: blue
# 3: yellow
# 4: orange
# 5: purple

# %%
index = 0
print (colors)
colors_popped = []
length = len(colors)
print (length)
while index < length:
    colors_popped.append(colors.pop())
    index+=1

print (f"colors: {colors}")
print (f"colors_popped: {colors_popped}")
# Out:
# ['red', 'green', 'blue', 'yellow', 'orange', 'purple']
# 6
# colors: []
# colors_popped: ['purple', 'orange', 'yellow', 'blue', 'green', 'red']

# %%
colors
# Out:
# []

# %%
colors_popped.extend(["yellow", "orange"])

# %%
print (colors_popped)
# Out:
# ['purple', 'orange', 'yellow', 'blue', 'green', 'red', 'yellow', 'orange']

# %%
colors = colors_popped.copy()

# %%
print (colors)
# Out:
# ['purple', 'orange', 'yellow', 'blue', 'green', 'red', 'yellow', 'orange']

# %%
colors.remove("yellow")

# %%
print (colors)
# Out:
# ['purple', 'orange', 'blue', 'green', 'red', 'yellow', 'orange']

# %%
colors
# Out:
# ['purple', 'orange', 'blue', 'green', 'red', 'yellow', 'orange']

# %%
for color in colors:
    if color == "orange":
        colors.remove(color)
print (colors)
# Out:
# ['purple', 'blue', 'green', 'red', 'yellow']

# %%
index = 0

colors = ["red", "green", "blue", "yellow", "orange", "purple"]

while index < len(colors):
    print(f"{index}: {colors[index]}")
    index+=1
# Out:
# 0: red
# 1: green
# 2: blue
# 3: yellow
# 4: orange
# 5: purple

# %%
colors.extend(["yellow", "orange"])

# %%
i=0
while i < len(colors):
    if colors[i] == "orange":
        colors.remove(colors[i])
    i+=1
print (colors)
# Out:
# ['red', 'green', 'blue', 'yellow', 'purple', 'yellow']

# %%
colors = colors_popped.copy()

# %%
colors
# Out:
# ['purple', 'orange', 'yellow', 'blue', 'green', 'red', 'yellow', 'orange']

# %%
new_colors = [color for color in colors if color != "orange"]
print (new_colors)
# Out:
# ['purple', 'yellow', 'blue', 'green', 'red', 'yellow']

# %%
print (colors)
colors.index("yellow")
# Out:
# ['purple', 'orange', 'yellow', 'blue', 'green', 'red', 'yellow', 'orange']
# 2

# %%
print (colors.count("yellow"))
print (colors.count("red"))
# Out:
# 2
# 1

# %%
print (colors.reverse())

print (colors)
# Out:
# None
# ['purple', 'orange', 'yellow', 'blue', 'green', 'red', 'yellow', 'orange']

# %%
str1 = ",".join(colors)
print (str1)
# Out:
# purple,orange,yellow,blue,green,red,yellow,orange

# %%
list1 = str1.split(",")

# %%
print (list1)
# Out:
# ['purple', 'orange', 'yellow', 'blue', 'green', 'red', 'yellow', 'orange']

# %%
print (name)
list(name)
# Out:
# Sujay
# ['S', 'u', 'j', 'a', 'y']
